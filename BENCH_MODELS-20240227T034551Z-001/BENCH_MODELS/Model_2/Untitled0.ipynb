# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorrt

# !/usr/src/tensorrt/bin/trtexec --onnx=/content/drive/MyDrive/BENCH_MODELS/MODEL_1_ALEXNET/Model_2/vgg19.onnx --saveEngine=/content/drive/MyDrive/BENCH_MODELS/MODEL_1_ALEXNET/Model_2/vgg19.onnx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b1f1941af797> in <cell line: 1>()
# ----> 1 import tensorrt
#       2
#       3 get_ipython().system('/usr/src/tensorrt/bin/trtexec --onnx=/content/drive/MyDrive/BENCH_MODELS/MODEL_1_ALEXNET/Model_2/vgg19.onnx --saveEngine=/content/drive/MyDrive/BENCH_MODELS/MODEL_1_ALEXNET/Model_2/vgg19.onnx')
#
# ModuleNotFoundError: No module named 'tensorrt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt-get install docker.io
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor bridge-utils containerd dns-root-data dnsmasq-base iptables libip6tc2
#   libnetfilter-conntrack3 libnfnetlink0 libnftnl11 netbase netcat netcat-openbsd pigz runc
#   ubuntu-fan
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ifupdown aufs-tools btrfs-progs cgroupfs-mount
#   | cgroup-lite debootstrap docker-doc rinse zfs-fuse | zfsutils firewalld nftables
# The following NEW packages will be installed:
#   apparmor bridge-utils containerd dns-root-data dnsmasq-base docker.io iptables libip6tc2
#   libnetfilter-conntrack3 libnfnetlink0 libnftnl11 netbase netcat netcat-openbsd pigz runc
#   ubuntu-fan
# 0 upgraded, 17 newly installed, 0 to remove and 32 not upgraded.
# Need to get 71.0 MB of archives.
# After this operation, 273 MB of additional disk space will be used.
# ...

# %%
# Step 1: Pull the Triton Inference Server Docker container
# !docker pull nvcr.io/nvidia/tritonserver:21.02-py3
# Out:
# Cannot connect to the Docker daemon at unix:///var/run/docker.sock. Is the docker daemon running?
